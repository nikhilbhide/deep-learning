# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.figure import Figure

# %%
t = 10
fs = 50000
samples = np.linspace(0, t, int(fs*t), endpoint=False)

# %%
samples
# Out:
# array([0.00000e+00, 2.00000e-05, 4.00000e-05, ..., 9.99994e+00,
#        9.99996e+00, 9.99998e+00])

# %%
N = 1000
samples = np.sin(0.09*np.arange(N))
plt.plot(x)

# %%
T = 10
X = []
Y = []
for t in range(len(samples) - T):
  x = samples[t:t+T]
  y = samples[t+T]
  X.append(x)
  Y.append(y)

# %%
X = np.array(X).reshape(-1, T)
Y = np.array(Y).reshape(-1, 1)
